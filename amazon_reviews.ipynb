# %%
# Libraries
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
url = 'https://www.amazon.com/-/en/frecuencia-actualizaci%C3%B3n-sincronizaci%C3%B3n-adaptativa-anticipada/dp/B0CVM2GJCN/ref=sr_1_3'

HEADERS = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Upgrade-Insecure-Requests": "1",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
}

response = requests.get(url, headers=HEADERS)
soup = bs(response.text, "html.parser")

# %% [markdown]
# ### Using css selectors

# %%
# css selectors | get review content

reviews_element = soup.select('div[data-hook="review"]')
# reviews_element = soup.select('div[data-hook="review"]', limit=8)
reviews_data = []
base_url = 'https://www.amazon.com'

for review in reviews_element:
    r_author_element = review.select_one('span.a-profile-name')
    r_author = r_author_element.text if r_author_element else None

    r_rating_element = review.select_one('i[data-hook="review-star-rating"] span.a-icon-alt')
    r_rating = r_rating_element.text.replace(' out of 5 stars', '') if r_rating_element else 'No rating'

    r_title_element = review.select_one('a[data-hook="review-title"]')
    r_title_span_element = r_title_element.select_one("span:not([class])") if r_title_element else None
    r_title = r_title_span_element.text if r_title_span_element else None

    r_body_element = review.select_one('span[data-hook="review-body"] span')
    r_body = r_body_element.text if r_body_element else 'No review body'

    r_date_element = review.select_one('span[data-hook="review-date"]')
    r_date = r_date_element.text if r_date_element else 'No review date'

    r_href_element = review.select_one('a[data-hook="review-title"]')
    r_href = r_href_element.get('href') if r_href_element else None
    full_url = base_url + r_href if r_href else None

    # Add the data to the list
    reviews_data.append({
        'review_author': r_author,
        'review_rating': r_rating,
        'review_title': r_title,
        'review_body': r_body,
        'review_date': r_date,
        'review_href': full_url
    })

# Output the list of dictionaries
print(reviews_data)
# Out:
# [{'review_author': 'Fizzie', 'review_rating': '5.0', 'review_title': 'Great Monitor', 'review_body': 'Works flawlessly.  Gives a nice picture and is very reasonably priced.  Very happy with this purchase.', 'review_date': 'Reviewed in the United States on August 17, 2024', 'review_href': 'https://www.amazon.com/gp/customer-reviews/R249JAPXUXXVLA/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'}, {'review_author': 'MICHAEL R.', 'review_rating': '5.0', 'review_title': 'Very affordable (Basic monitor) upgrade, best warranty found!', 'review_body': 'Bought as a replacement for my HP20" monitor and have found it to be awesome for the price!  Best warranty listed anywhere, and hopefully will not need, but for the price you cannot beat this deal.PRO\'s  Very bright, good OSD, easy to set up, plug and play, registered and using same day as delivered.CONS\'s  Does NOT come with a user manual (NO how to use/set OSD settings, specifications of the monitor, recommended settings, etc.  The "Important Information Manual" has 65 pages with 5 pages in English that have no useful information for the monitor) Had to google search to verify the listing specs and still have not found a PDF for "How to set up settings via OSD" for the recommend use and the effects of each setting, especially the low blue mode. The PDF files on the listing are for a different model, and one is for a coffee pot!!  But did verify that the listed specs are legit.  Bought this as an upgrade and to be able to see the screen at a normal distance with my glasses but had to change settings to a 1360 X 1024 from the default of 1920 X 1080 as that setting was too small for me to read and would only occupy 80% of the screen.  I am full screen at the changed setting.  Would like to have more information about the settings via OSD (On Screen Display), but overall, very happy with this monitor and recommend for anyone wanting to upgrade an older desktop PC (or laptop) at an awesome price and best warranty listed!!PS I\'m NOT a gamer, general use, research, FB, Email, bill pay and movies :)) Hence the no rating for gaming :)) But, my 2GB video card looks pretty awesome also and better colors than my old 20" monitor.  When I upgrade my Desktop will use this monitor as a secondary/dual monitor set up!', 'review_date': 'Reviewed in the United States on February 22, 2024', 'review_href': 'https://www.amazon.com/gp/customer-reviews/R29QPQ1811DS22/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'}, {'review_author': 'MaltipooMomma', 'review_rating': '5.0', 'review_title': 'Perfect picture', 'review_body': 'Very sturdy and easy to use. Great appearance. Performs very good. The brightness is perfect. Would definitely purchase again.', 'review_date': 'Reviewed in the United States on August 19, 2024', 'review_href': 'https://www.amazon.com/gp/customer-reviews/R3VBMUJ8G95HKA/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'}, {'review_author': 'Florian', 'review_rating': '4.0', 'review_title': 'Excellent Value Monitor with Great Performance and Warranty', 'review_body': "The PHILIPS 22-inch Class Thin Full HD Monitor is a fantastic addition to any workspace, offering a crisp and vibrant 1920 x 1080 resolution that delivers clear and sharp visuals. Its 75Hz refresh rate ensures smooth performance, making it ideal for tasks ranging from document editing to watching videos. The monitor's HDMI and VGA ports provide easy connectivity, and the VESA mount compatibility allows for flexible positioning.Setting up the monitor is straightforward, and it works seamlessly with both PC and Mac systems. The bright display and good on-screen display (OSD) settings enhance the user experience. However, the lack of a comprehensive user manual can be a drawback, requiring users to search online for setup information.The monitor's eye protection feature helps reduce fatigue during long hours of use, and the stylish bezel-free design fits well in any environment. The 4-year advance replacement warranty is an excell ...

# %%
reviews_data
# Out:
# [{'review_author': 'Fizzie',
#   'review_rating': '5.0',
#   'review_title': 'Great Monitor',
#   'review_body': 'Works flawlessly.  Gives a nice picture and is very reasonably priced.  Very happy with this purchase.',
#   'review_date': 'Reviewed in the United States on August 17, 2024'},
#  {'review_author': 'MICHAEL R.',
#   'review_rating': '5.0',
#   'review_title': 'Very affordable (Basic monitor) upgrade, best warranty found!',
#   'review_body': 'Bought as a replacement for my HP20" monitor and have found it to be awesome for the price!  Best warranty listed anywhere, and hopefully will not need, but for the price you cannot beat this deal.PRO\'s  Very bright, good OSD, easy to set up, plug and play, registered and using same day as delivered.CONS\'s  Does NOT come with a user manual (NO how to use/set OSD settings, specifications of the monitor, recommended settings, etc.  The "Important Information Manual" has 65 pages with 5 pages in English that have no useful information for the monitor) Had to google search to verify the listing specs and still have not found a PDF for "How to set up settings via OSD" for the recommend use and the effects of each setting, especially the low blue mode. The PDF files on the listing are for a different model, and one is for a coffee pot!!  But did verify that the listed specs are legit.  Bought this as an upgrade and to be able to see the screen at a normal distance with my glasses but had to change settings to a 1360 X 1024 from the default of 1920 X 1080 as that setting was too small for me to read and would only occupy 80% of the screen.  I am full screen at the changed setting.  Would like to have more information about the settings via OSD (On Screen Display), but overall, very happy with this monitor and recommend for anyone wanting to upgrade an older desktop PC (or laptop) at an awesome price and best warranty listed!!PS I\'m NOT a gamer, general use, research, FB, Email, bill pay and movies :)) Hence the no rating for gaming :)) But, my 2GB video card looks pretty awesome also and better colors than my old 20" monitor.  When I upgrade my Desktop will use this monitor as a secondary/dual monitor set up!',
#   'review_date': 'Reviewed in the United States on February 22, 2024'},
#  {'review_author': 'MaltipooMomma',
#   'review_rating': '5.0',
#   'review_title': 'Perfect picture',
#   'review_body': 'Very sturdy and easy to use. Great appearance. Performs very good. The brightness is perfect. Would definitely purchase again.',
#   'review_date': 'Reviewed in the United States on August 19, 2024'},
#  {'review_author': 'Florian',
#   'review_rating': '4.0',
#   'review_title': 'Excellent Value Monitor with Great Performance and Warranty',
#   'review_body': "The PHILIPS 22-inch Class Thin Full HD Monitor is a fantastic addition to any workspace, offering a crisp and vibrant 1920 x 1080 resolution that delivers clear and sharp visuals. Its 75Hz refresh rate ensures smooth performance, making it ideal for tasks ranging from document editing to watching videos. The monitor's HDMI and VGA ports provide easy connectivity, and the VESA mount compatibility allows for flexible positioning.Setting up the monitor is straightforward, and it works seamlessly with both PC and Mac systems. The bright display and good on-screen display (OSD) settings enhance the user experience. However, the lack of a comprehensive user manual can be a drawback, requiring users to search online for setup information.The monitor's eye protection feature helps reduce fatigue during long hours of use, and the stylish bezel-free design fits well in any environment. The 4-year advance replacement warranty is an excellent bonus, offering peace of mind for a durable and reliable product.",
#   'review_date': 'Reviewed in the United States on July 8, 2024'},
#  {'review_author': 'clm',
#   'review_rating': '5.0',
#   'review_title': 'Perfect size, nice quality.',
#   'review_body': 'Neither too small nor too large, and nice resolution at a good price.',
#   'review_date': 'Reviewed in the United States on August 13, 2024'},
#  {'review_author': 'Ted',
#   'review_rating': '5.0',
#   'review_title': 'Has a nice picture',
#   'review_body': 'I am happy with the monitor.  It came with an HDMI cable, and it was plug and play.The monitor has some nice preset display features, such as easy read, office, photo, movie, game, economy, low blue mode, off.I am using the monitor for a home office and have been using it for a week and have had no issues with it.',
#   'review_date': 'Reviewed in the United States on August 9, 2024'},
#  {'review_author': 'Abdul',
#   'review_rating': '5.0',
#   'review_title': 'Good cheap name brand',
#   'review_body': 'It’s a good cheap name brand monitor that has Hdmi and the brightness is good. The appearance is good. easy to use and connects to my laptop.',
#   'review_date': 'Reviewed in the United States on August 24, 2024'},
#  {'review_author': 'Diana',
#   'review_rating': '5.0',
#   'review_title': 'It works',
#   'review_body': 'The monitor is a great price and works well the quality is great.perfect for my home office.',
#   'review_date': 'Reviewed in the United States on August 20, 2024'}]

# %%
df_reviews_data = pd.DataFrame(reviews_data)
df_reviews_data
# Out:
#       review_author review_rating  \
# 0            Fizzie           5.0
# 1        MICHAEL R.           5.0
# 2     MaltipooMomma           5.0
# 3           Florian           4.0
# 4               clm           5.0
# 5               Ted           5.0
# 6             Abdul           5.0
# 7             Diana           5.0
# 8            Osouky     No rating
# 9        Mario Díaz     No rating
# 10            E Lee     No rating
# 11   Jacques Legare     No rating
# 12  Nathan Carriere     No rating
#
#                                          review_title  \
# 0                                       Great Monitor
# 1   Very affordable (Basic monitor) upgrade, best ...
# 2                                     Perfect picture
# 3   Excellent Value Monitor with Great Performance...
# 4                         Perfect size, nice quality.
# 5                                  Has a nice picture
# 6                               Good cheap name brand
# 7                                            It works
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                           review_body  \
# 0   Works flawlessly.  Gives a nice picture and is...
# 1   Bought as a replacement for my HP20" monitor a...
# 2   Very sturdy and easy to use. Great appearance....
# 3   The PHILIPS 22-inch Class Thin Full HD Monitor...
# 4   Neither too small nor too large, and nice reso...
# 5   I am happy with the monitor.  It came with an ...
# 6   It’s a good cheap name brand monitor that has ...
# 7   The monitor is a great price and works well th...
# 8   Cuando salio el ultimo capitulo de Demons Slay...
# 9   Lo compré porque tiene una muy buena resolució...
# 10  I got this to replace my Dell P-Series 24 inch...
# 11                            Belle finition d'images
# 12  These are specialized for a multi-monitor work...
#
#                                           review_date  \
# 0    Reviewed in the United States on August 17, 2024
# 1   Reviewed in the United States on February 22, ...
# 2    Reviewed in the United States on August 19, 2024
# 3       Reviewed in the United States on July 8, 2024
# 4    Reviewed in the United States on August 13, 2024
# 5     Reviewed in the United States on August 9, 2024
# 6    Reviewed in the United States on August 24, 2024
# 7    Reviewed in the United States on August 20, 2024
# 8                Reviewed in Mexico on August 9, 2024
# 9              Reviewed in Mexico on November 2, 2023
# 10              Reviewed in Canada on October 5, 2023
# 11               Reviewed in Canada on April 19, 2022
# 12                 Reviewed in Canada on June 9, 2021
#
#                                           review_href
# 0   https://www.amazon.com/gp/customer-reviews/R24...
# 1   https://www.amazon.com/gp/customer-reviews/R29...
# 2   https://www.amazon.com/gp/customer-reviews/R3V...
# 3   https://www.amazon.com/gp/customer-reviews/R3O...
# 4   https://www.amazon.com/gp/customer-reviews/R3C...
# 5   https://www.amazon.com/gp/customer-reviews/RKX...
# 6   https://www.amazon.com/gp/customer-reviews/R3R...
# 7   https://www.amazon.com/gp/customer-reviews/R1Y...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None

# %% [markdown]
# ### Using find | find_all

# %%
reviews_element = soup.find_all('div', {'data-hook': 'review'}, limit=8)
reviews_data = []
base_url = 'https://www.amazon.com'

for review in reviews_element:
    r_author_element = review.find('span', class_='a-profile-name')
    r_author = r_author_element.text if r_author_element else None

    r_rating_element = review.find('i', {'data-hook': 'review-star-rating'})
    r_rating = r_rating_element.text.replace(' out of 5 stars', '') if r_rating_element else None

    r_title_element = review.find('a', {'data-hook': 'review-title'})
    r_title_span_element = r_title_element.find('span', class_=False) if r_title_element else None
    r_title = r_title_span_element.text if r_title_span_element else None

    r_body_element = review.find('span', {'data-hook': 'review-body'}).find('span')
    r_body = r_body_element.text if r_body_element else None

    r_date_element = review.find('span', {'data-hook': 'review-date'})
    r_date = r_date_element.text if r_date_element else None

    r_href_element = review.find('a', {'data-hook': 'review-title'})
    r_href = r_href_element.get('href') if r_href_element else None
    full_url = base_url + r_href if r_href else None

    reviews_data.append({
        'review_author': r_author,
        'review_rating': r_rating,
        'review_title': r_title,
        'review_body': r_body,
        'review_date': r_date,
        'review_href': full_url
    })

reviews_data
# Out:
# [{'review_author': 'Fizzie',
#   'review_rating': '5.0',
#   'review_title': 'Great Monitor',
#   'review_body': 'Works flawlessly.  Gives a nice picture and is very reasonably priced.  Very happy with this purchase.',
#   'review_date': 'Reviewed in the United States on August 17, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R249JAPXUXXVLA/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'MICHAEL R.',
#   'review_rating': '5.0',
#   'review_title': 'Very affordable (Basic monitor) upgrade, best warranty found!',
#   'review_body': 'Bought as a replacement for my HP20" monitor and have found it to be awesome for the price!  Best warranty listed anywhere, and hopefully will not need, but for the price you cannot beat this deal.PRO\'s  Very bright, good OSD, easy to set up, plug and play, registered and using same day as delivered.CONS\'s  Does NOT come with a user manual (NO how to use/set OSD settings, specifications of the monitor, recommended settings, etc.  The "Important Information Manual" has 65 pages with 5 pages in English that have no useful information for the monitor) Had to google search to verify the listing specs and still have not found a PDF for "How to set up settings via OSD" for the recommend use and the effects of each setting, especially the low blue mode. The PDF files on the listing are for a different model, and one is for a coffee pot!!  But did verify that the listed specs are legit.  Bought this as an upgrade and to be able to see the screen at a normal distance with my glasses but had to change settings to a 1360 X 1024 from the default of 1920 X 1080 as that setting was too small for me to read and would only occupy 80% of the screen.  I am full screen at the changed setting.  Would like to have more information about the settings via OSD (On Screen Display), but overall, very happy with this monitor and recommend for anyone wanting to upgrade an older desktop PC (or laptop) at an awesome price and best warranty listed!!PS I\'m NOT a gamer, general use, research, FB, Email, bill pay and movies :)) Hence the no rating for gaming :)) But, my 2GB video card looks pretty awesome also and better colors than my old 20" monitor.  When I upgrade my Desktop will use this monitor as a secondary/dual monitor set up!',
#   'review_date': 'Reviewed in the United States on February 22, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R29QPQ1811DS22/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'MaltipooMomma',
#   'review_rating': '5.0',
#   'review_title': 'Perfect picture',
#   'review_body': 'Very sturdy and easy to use. Great appearance. Performs very good. The brightness is perfect. Would definitely purchase again.',
#   'review_date': 'Reviewed in the United States on August 19, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R3VBMUJ8G95HKA/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'Florian',
#   'review_rating': '4.0',
#   'review_title': 'Excellent Value Monitor with Great Performance and Warranty',
#   'review_body': "The PHILIPS 22-inch Class Thin Full HD Monitor is a fantastic addition to any workspace, offering a crisp and vibrant 1920 x 1080 resolution that delivers clear and sharp visuals. Its 75Hz refresh rate ensures smooth performance, making it ideal for tasks ranging from document editing to watching videos. The monitor's HDMI and VGA ports provide easy connectivity, and the VESA mount compatibility allows for flexible positioning.Setting up the monitor is straightforward, and it works seamlessly with both PC and Mac systems. The bright display and good on-screen display (OSD) settings enhance the user experience. However, the lack of a comprehensive user manual can be a drawback, requiring users to search online for setup information.The monitor's eye protection feature helps reduce fatigue during long hours of use, and the stylish bezel-free design fits well in any environment. The 4-year advance replacement warranty is an excellent bonus, offering peace of mind for a durable and reliable product.",
#   'review_date': 'Reviewed in the United States on July 8, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R3O3NQ67IE59WU/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'clm',
#   'review_rating': '5.0',
#   'review_title': 'Perfect size, nice quality.',
#   'review_body': 'Neither too small nor too large, and nice resolution at a good price.',
#   'review_date': 'Reviewed in the United States on August 13, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R3C3IYYEVAKEHI/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'Ted',
#   'review_rating': '5.0',
#   'review_title': 'Has a nice picture',
#   'review_body': 'I am happy with the monitor.  It came with an HDMI cable, and it was plug and play.The monitor has some nice preset display features, such as easy read, office, photo, movie, game, economy, low blue mode, off.I am using the monitor for a home office and have been using it for a week and have had no issues with it.',
#   'review_date': 'Reviewed in the United States on August 9, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/RKXP3LXTN10ND/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'Abdul',
#   'review_rating': '5.0',
#   'review_title': 'Good cheap name brand',
#   'review_body': 'It’s a good cheap name brand monitor that has Hdmi and the brightness is good. The appearance is good. easy to use and connects to my laptop.',
#   'review_date': 'Reviewed in the United States on August 24, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R3R0B0HFZ9XILH/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'},
#  {'review_author': 'Diana',
#   'review_rating': '5.0',
#   'review_title': 'It works',
#   'review_body': 'The monitor is a great price and works well the quality is great.perfect for my home office.',
#   'review_date': 'Reviewed in the United States on August 20, 2024',
#   'review_href': 'https://www.amazon.com/gp/customer-reviews/R1YDUFRKKGNNQM/ref=cm_cr_dp_d_rvw_ttl?ie=UTF8&ASIN=B0CVM2GJCN'}]
